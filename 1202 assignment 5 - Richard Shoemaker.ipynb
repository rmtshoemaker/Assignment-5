# %% [markdown]
# # Import Required Programs

# %%
import glob
import numpy
import pandas as pd
import matplotlib
import matplotlib.pyplot 
import numpy as np

# %% [markdown]
# # Define visualize() Function

# %%
def visualize(filename):
    #for file in filename:
    data = numpy.loadtxt(fname=filename, delimiter=',')
        
    fig,a = plt.subplots()
    x = data
    
    a.plot(np.mean(data, axis=0), color = "r", label = "Average")
    a.plot(np.min(data,axis=0), color = "b", label = "Min")
    a.plot(np.max(data,axis=0), color = "g", label = "Max")
    
    plt.legend()
   

    plt.show()

# %% [markdown]
# # Define identify_issue() Function

# %%
def  identify_issues(filename):
    """Identify issues with the datasets"""
    numpy.loadtxt(fname=filename)
    #Construct Elif statement
    if data.max(feature=0)==0 and data.max(feature=20)==0:
        print('I doubt the integrity of this dataset')
    
    elif data.min()==0:
        print('What is happening?')
        
    else:
        print('dataset looks good')

# %% [markdown]
# # Sort Datasets and Execute Functions

# %%
import matplotlib.pyplot as plt
"""Sort datasets into list"""
dataset = sorted(glob.glob('data*.csv'))

print(dataset[0])

#Execute fuctions to datasets
for datasets in dataset[:4]:
    visualize(datasets)
# Out:
# data-01.csv

# %% [markdown]
# identify_issue() was not included as it resulted in an error and could not be completed in time.
